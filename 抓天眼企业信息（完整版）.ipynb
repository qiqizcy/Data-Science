# %%
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote

# %%
company_list2 = [['赛维时代'],
['林氏木业'],
['易世通达'],
['豪雅集团'],
['亚飞'],
['易佰'],
['致欧'],
['傲基'],
['有棵树'],
['绿联'],
['罗马仕'],
['利朗达'],
['中诺通讯'],
['公狼网络'],
['合趣'],
['嘉立创'],
['沃克非凡'],
['吉迩（电子烟）'],
['亚声威格'],
['上海司顺'],
['广州细刻'],
['广州棒谷'],
['义乌夏歌'],
['西安澳鹏'],
['莉莉丝'],
['波克城市'],
['哔哩哔哩'],
['友塔'],
['沐瞳'],
['米哈游'],
['盛趣'],
['心动']]

# %%
for i in range(len(company_list2)):
    company = company_list2[i][0]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/search?key={}'.format(quote(company))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('div',{'class':'index_search-box__7YVh6'})[0]
    company_list2[i].append(info.find_all('a',{'class':'link-click'})[1].text)
    company_list2[i].append(info.find_all('span')[2].text)

# %%
company_list2
# Out:
# [['赛维时代', '陈文平', '2012-05-31'],
#  ['林氏木业', '林佐义', '2014-12-29'],
#  ['易世通达', '周井生', '2016-05-24'],
#  ['豪雅集团', '徐琦莹', '1998-03-02'],
#  ['亚飞', '孙彦飞', '2010-08-22'],
#  ['易佰', '胡范金', '2011-10-20'],
#  ['致欧', '宋川', '2010-01-08'],
#  ['傲基', '陆海传', '2010-09-13'],
#  ['有棵树', '肖四清', '2010-04-20'],
#  ['绿联', '何梦新', '2012-03-16'],
#  ['罗马仕', '雷桂斌', '2012-03-13'],
#  ['利朗达', '戴怡青', '2011-03-10'],
#  ['中诺通讯', '杨韬', '1997-10-22'],
#  ['公狼网络', '王晓锋', '2011-09-30'],
#  ['合趣', '田云仙', '2016-08-01'],
#  ['嘉立创', '袁江涛', '2006-11-15'],
#  ['沃克非凡', '许龙华', '2014-05-06'],
#  ['吉迩（电子烟）', '赵波洋', '2014-02-10'],
#  ['亚声威格', '周虎', '2008-02-01'],
#  ['上海司顺', '焦如宝', '2018-06-25'],
#  ['广州细刻', '王凡', '2015-10-22'],
#  ['广州棒谷', '邹欣', '2009-02-23'],
#  ['义乌夏歌', '赖万兴', '2014-08-19'],
#  ['西安澳鹏', '卢威', '2014-05-30'],
#  ['莉莉丝', '王信文', '2013-05-10'],
#  ['波克城市', '徐仁彬', '2010-04-08'],
#  ['哔哩哔哩', '郑彬炜', '2016-12-30'],
#  ['友塔', '蔡华林', '2018-04-02'],
#  ['沐瞳', '袁菁', '2014-01-26'],
#  ['米哈游', '蔡浩宇', '2012-02-13'],
# ...

# %%
for i in range(len(company_list2)):
    company = company_list2[i][0]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/search?key={}'.format(quote(company))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('a',{'class':'index_alink__zcia5 link-click'})[0]
    code = info['href'].split('/')[-1]
    company_list2[i].append(code)

# %%
company_list2
# Out:
# [['赛维时代', '陈文平', '2012-05-31', '3402778699'],
#  ['林氏木业', '林佐义', '2014-12-29', '2325134924'],
#  ['易世通达', '周井生', '2016-05-24', '2481675316'],
#  ['豪雅集团', '徐琦莹', '1998-03-02', '2803878450'],
#  ['亚飞', '孙彦飞', '2010-08-22', '2316226845'],
#  ['易佰', '胡范金', '2011-10-20', '2348880564'],
#  ['致欧', '宋川', '2010-01-08', '3089072356'],
#  ['傲基', '陆海传', '2010-09-13', '3329240447'],
#  ['有棵树', '肖四清', '2010-04-20', '1008579091'],
#  ['绿联', '何梦新', '2012-03-16', '1420260418'],
#  ['罗马仕', '雷桂斌', '2012-03-13', '1446548594'],
#  ['利朗达', '戴怡青', '2011-03-10', '2349024002'],
#  ['中诺通讯', '杨韬', '1997-10-22', '18655496'],
#  ['公狼网络', '王晓锋', '2011-09-30', '2353688990'],
#  ['合趣', '田云仙', '2016-08-01', '2411012067'],
#  ['嘉立创', '袁江涛', '2006-11-15', '572256991'],
#  ['沃克非凡', '许龙华', '2014-05-06', '3237703642'],
#  ['吉迩（电子烟）', '赵波洋', '2014-02-10', '2563876669'],
#  ['亚声威格', '周虎', '2008-02-01', '1331051834'],
#  ['上海司顺', '焦如宝', '2018-06-25', '3182723033'],
#  ['广州细刻', '王凡', '2015-10-22', '2352422408'],
# ...

# %%
for i in range(len(company_list2)):
    code = company_list2[i][3]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/company/{}'.format(quote(code))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('script',{'id':'__NEXT_DATA__'})
    strl = info[0].text
    regex1 = r'(?<="staffNumRange":).[0-9_-\u4e00-\u9fa5]*'
    num = re.findall(regex1,strl)
    regex2 = r'(?<="industry":).[\u4e00-\u9fa5]*'
    industry = re.findall(regex2,strl)
    company_list2[i].append(num[0].replace('"',''))
    company_list2[i].append(industry[0].replace('"',''))

# %%
company_list2
# Out:
# [['赛维时代', '陈文平', '2012-05-31', '3402778699', '50-99', '软件和信息技术服务业'],
#  ['林氏木业', '林佐义', '2014-12-29', '2325134924', '1000-4999', '零售业'],
#  ['易世通达', '周井生', '2016-05-24', '2481675316', '50-99', '批发业'],
#  ['豪雅集团', '徐琦莹', '1998-03-02', '2803878450', '100-499', '批发业'],
#  ['亚飞', '孙彦飞', '2010-08-22', '2316226845', '100-499', '零售业'],
#  ['易佰', '胡范金', '2011-10-20', '2348880564', '1000-4999', '批发业'],
#  ['致欧', '宋川', '2010-01-08', '3089072356', '500-999', '软件和信息技术服务业'],
#  ['傲基', '陆海传', '2010-09-13', '3329240447', '1000-4999', '软件和信息技术服务业'],
#  ['有棵树', '肖四清', '2010-04-20', '1008579091', '500-999', '软件和信息技术服务业'],
#  ['绿联', '何梦新', '2012-03-16', '1420260418', '500-999', '零售业'],
#  ['罗马仕', '雷桂斌', '2012-03-13', '1446548594', '100-499', '批发业'],
#  ['利朗达', '戴怡青', '2011-03-10', '2349024002', '100-499', '商务服务业'],
#  ['中诺通讯', '杨韬', '1997-10-22', '18655496', '100-499', '计算机'],
#  ['公狼网络', '王晓锋', '2011-09-30', '2353688990', '50-99', '批发业'],
# ...

# %%
import pandas as pd
cl2 = pd.DataFrame(company_list2)
cl2.columns = ['company','legal_rep','launch_time','code','staff_num','industry']
result2 = cl2[['company','legal_rep','launch_time','staff_num','industry']]

# %%
result2.replace('n','',inplace=True)
# Out:
# C:\Users\lfn\AppData\Local\Temp\ipykernel_20552\156098448.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result2.replace('n','',inplace=True)

# %%
result2
# Out:
#     company legal_rep launch_time  staff_num    industry
# 0      赛维时代       陈文平  2012-05-31      50-99  软件和信息技术服务业
# 1      林氏木业       林佐义  2014-12-29  1000-4999         零售业
# 2      易世通达       周井生  2016-05-24      50-99         批发业
# 3      豪雅集团       徐琦莹  1998-03-02    100-499         批发业
# 4        亚飞       孙彦飞  2010-08-22    100-499         零售业
# 5        易佰       胡范金  2011-10-20  1000-4999         批发业
# 6        致欧        宋川  2010-01-08    500-999  软件和信息技术服务业
# 7        傲基       陆海传  2010-09-13  1000-4999  软件和信息技术服务业
# 8       有棵树       肖四清  2010-04-20    500-999  软件和信息技术服务业
# 9        绿联       何梦新  2012-03-16    500-999         零售业
# 10      罗马仕       雷桂斌  2012-03-13    100-499         批发业
# 11      利朗达       戴怡青  2011-03-10    100-499       商务服务业
# 12     中诺通讯        杨韬  1997-10-22    100-499         计算机
# 13     公狼网络       王晓锋  2011-09-30      50-99         批发业
# 14       合趣       田云仙  2016-08-01    100-499  软件和信息技术服务业
# ...

# %%
# from openpyxl import load_workbook
# df1 = pd.DataFrame(pd.read_excel('C:/Users/lfn/Desktop/companych1.xlsx')) #读取原数据文件和表
# book=load_workbook('C:/Users/lfn/Desktop/companych1.xlsx')
# writer = pd.ExcelWriter('C:/Users/lfn/Desktop/companych1.xlsx',engine='openpyxl')
# writer.book = book
# df_rows = df1.shape[0] #获取原数据的行数
# result2.to_excel(writer, sheet_name='a', startrow=df_rows+1, index=False, header=False)#将数据写入excel中的aa表,从第一个空行开始写
# writer.save()#保存

# %%
result2.to_excel('C:/Users/lfn/Desktop/companych2.xlsx',encoding = 'utf-8_sig')

# %%
company_list3 = [
['欢乐互娱'],
['纵游(DeNA中国)'],
['黑桃互动'],
['鹰角'],
['悠星'],
['方趣'],
['敬游'],
['智多鱼'],
['番糖'],
['域起'],
['绿岸'],
['游陆'],
['梦求网络'],
['可那（椰岛）'],
['散爆'],
['游牛'],
['骏梦游戏'],
['狂热网络'],
['跳跃网络'],
['拾梦文化'],
['怪猫'],
['七创社'],
['火溶'],
['沁游'],
['杭州边锋'],
['北京趣加'],
['北京奇艺世纪'],
['北京点点互动'],
['北京乐元素'],
['成都乐曼多'],
['福州龙腾简合'],
['北京麦吉太文'],
['厦门真有趣'],
['苏州爱洛克'],
['广州易幻'],
['北京奇异世纪'],
['EA上海'],
['育碧上海'],
['赛文斯'],
['亿科'],
['蓝标'],
['上海邑炎'],
['北京试玩互动'],
['武汉踏浪出海'],
['北京木瓜移动'],

['西安易点天下'],
['上海天擎'],
['大族激光智能装备'],
['云鲸智能'],
['理士'],
['德兰明海'],
['首航'],
['递四方'],
['凯迪海运'],
['运去哪'],
['好未来'],
['阿卡索外教网'],
['创维'],
['卓尔悦'],
['富图'],
['涂鸦智能'],
['小象互娱'],
['广州卓志'],
['中手游'],
['迷你玩'],
['星合'],
['禅游'],
['淘乐'],
['乐易']]

# %%
for i in range(len(company_list3)):
    company = company_list3[i][0]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/search?key={}'.format(quote(company))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('div',{'class':'index_search-box__7YVh6'})[0]
    company_list3[i].append(info.find_all('a',{'class':'link-click'})[1].text)
    company_list3[i].append(info.find_all('span')[2].text)

# %%
for i in range(len(company_list3)):
    company = company_list3[i][0]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/search?key={}'.format(quote(company))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('a',{'class':'index_alink__zcia5 link-click'})[0]
    code = info['href'].split('/')[-1]
    company_list3[i].append(code)

# %%
for i in range(len(company_list3)):
    code = company_list3[i][3]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/company/{}'.format(quote(code))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('script',{'id':'__NEXT_DATA__'})
    strl = info[0].text
    regex1 = r'(?<="staffNumRange":).[0-9_-\u4e00-\u9fa5]*'
    num = re.findall(regex1,strl)
    regex2 = r'(?<="industry":).[\u4e00-\u9fa5]*'
    industry = re.findall(regex2,strl)
    company_list3[i].append(num[0].replace('"',''))
    company_list3[i].append(industry[0].replace('"',''))

# %%
import pandas as pd
cl3 = pd.DataFrame(company_list3)
cl3.columns = ['company','legal_rep','launch_time','code','staff_num','industry']
result3 = cl3[['company','legal_rep','launch_time','staff_num','industry']]
result3.replace('n','',inplace=True)
#result3.to_excel('C:/Users/lfn/Desktop/companych3.xlsx',encoding = 'utf-8_sig')
# Out:
# C:\Users\lfn\AppData\Local\Temp\ipykernel_20552\2029791441.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result3.replace('n','',inplace=True)

# %%
pd.set_option('display.max_rows',None)
result3
# Out:
#        company            legal_rep launch_time  staff_num    industry
# 0         欢乐互娱                  时继江  2009-07-02    100-499  科技推广和应用服务业
# 1   纵游(DeNA中国)               OI JUN  2007-09-25    100-499  软件和信息技术服务业
# 2         黑桃互动                  王进强  2014-03-21      50-99    互联网和相关服务
# 3           鹰角                  黄一峰  2017-01-24    500-999  科技推广和应用服务业
# 4           悠星                   陈开  2014-08-14    100-499  科技推广和应用服务业
# 5           方趣                  方师恩  2015-06-16      50-99     专业技术服务业
# 6           敬游                   秦鹏  2014-09-16      50-99  科技推广和应用服务业
# 7          智多鱼                   吴灿  2020-04-14      50-99     研究和试验发展
# 8           番糖                  周永丰  2014-04-17    100-499  软件和信息技术服务业
# 9           域起                  朱柯彬  2013-10-22    100-499  科技推广和应用服务业
# 10          绿岸                   许帆  2008-11-28        280          传媒
# 11          游陆                  吴永波  2012-06-13      50-99     专业技术服务业
# ...

# %%
company_list4 = [['创梦天地（乐逗）'],
['灿和兄弟'],
['凉屋游戏'],
['风眼科技'],
['创酷'],
['九九互动'],
['第七大道'],
['星河互动（咸鱼游戏）'],
['易帆'],
['大梦龙途'],
['海拓时代'],
['奇迅新游'],
['闲闲互娱'],
['迅龙创威'],
['望尘'],
['上海沐瞳'],
['北京途游'],
['厦门家乡互动'],
['北京龙创悦动'],
['友谊时光'],
['爱洛克'],
['蜗牛游戏'],
['幻塔网络'],
['天魂网络'],
['五十一区工作室'],
['仙峰游戏'],
['风时网络'],
['开心盒子'],
['上海艾德威'],
['乐贝'],
['稀途跨境'],
['极易科技'],
['花无缺'],
['竹简信息技术'],
['凯帝丽莎'],
['柒零叁网络'],
['今心络捷'],
['克斯宝德'],
['征鸟信息技术'],
['丝路互联'],
['皮特商贸'],
['北京环球宜选'],
['无锡尚佰'],
['宝时德'],
['思杰马克丁'],
['大禹网络'],
['若态科技'],
['科瑞恩'],
['追觅科技'],
['拓拓工具'],
['融硅新能源'],
['箴全科技'],
['边锋']]

# %%
for i in range(len(company_list4)):
    company = company_list4[i][0]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/search?key={}'.format(quote(company))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('div',{'class':'index_search-box__7YVh6'})[0]
    company_list4[i].append(info.find_all('a',{'class':'link-click'})[1].text)
    company_list4[i].append(info.find_all('span')[2].text)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
#      13 soup = BeautifulSoup(html.text,features="html.parser")
#      14 info = soup.find_all('div',{'class':'index_search-box__7YVh6'})[0]
# ---> 15 company_list4[i].append(info.find_all('a',{'class':'link-click'})[1].text)
#      16 company_list4[i].append(info.find_all('span')[2].text)
#
# IndexError: list index out of range

# %%
for i in range(len(company_list4)):
    company = company_list4[i][0]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/search?key={}'.format(quote(company))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('a',{'class':'index_alink__zcia5 link-click'})[0]
    code = info['href'].split('/')[-1]
    company_list4[i].append(code)

# %%
company_list4
# Out:
# [['创梦天地（乐逗）', '28018614'],
#  ['灿和兄弟', '2329807362'],
#  ['凉屋游戏', '2353553204'],
#  ['风眼科技', '2352361040'],
#  ['创酷', '2329659653'],
#  ['九九互动', '3334397847'],
#  ['第七大道', '1137959681'],
#  ['星河互动（咸鱼游戏）', '1539090455'],
#  ['易帆', '2322222203'],
#  ['大梦龙途', '1586340489'],
#  ['海拓时代', '2406984170'],
#  ['奇迅新游', '2345387625'],
#  ['闲闲互娱', '3150009015'],
#  ['迅龙创威', '2347436213'],
#  ['望尘', '2321909813'],
#  ['上海沐瞳', '805494545'],
#  ['北京途游', '24596577'],
#  ['厦门家乡互动', '697677242'],
#  ['北京龙创悦动', '116288252'],
#  ['友谊时光', '3422245690'],
#  ['爱洛克', '2350607487'],
#  ['蜗牛游戏', '26982968'],
#  ['幻塔网络', '3403214770'],
#  ['天魂网络', '2349385793'],
#  ['五十一区工作室', '3192163323'],
#  ['仙峰游戏', '2976216454'],
#  ['风时网络', '3092217906'],
#  ['开心盒子', '752952090'],
#  ['上海艾德威', '343584407'],
#  ['乐贝', '2349595074'],
#  ['稀途跨境', '3478871131'],
#  ['极易科技', '2349253559'],
#  ['花无缺', '3272205901'],
#  ['竹简信息技术', '3192724381'],
#  ['凯帝丽莎', '4510059394'],
#  ['柒零叁网络', '2438769599'],
#  ['今心络捷', '2317562248'],
# ...

# %%
for i in range(27,51):
    code = company_list4[i][1]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/company/{}'.format(quote(code))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('script',{'id':'__NEXT_DATA__'})
    strl = info[0].text
    regex1 = r'(?<="staffNumRange":).[0-9_-\u4e00-\u9fa5]*'
    num = re.findall(regex1,strl)
    regex2 = r'(?<="industry":).[\u4e00-\u9fa5]*'
    industry = re.findall(regex2,strl)
    company_list4[i].append(num[0].replace('"',''))
    company_list4[i].append(industry[0].replace('"',''))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
#       1 for i in range(27,52):
# ----> 2     code = company_list4[i][1]
#       3     headers = {
#       4 	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
#       5     'Accept-Encoding': 'gzip, deflate, br',
#    (...)
#       9 	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
#      10 }
#      11     url = 'https://www.tianyancha.com/company/{}'.format(quote(code))
#
# IndexError: list index out of range

# %%
len(company_list4)
# Out:
# 51

# %%
cl4 = pd.DataFrame(company_list4)
cl4.columns = ['company','code','staff_num','industry']
result4 = cl4[['company','staff_num','industry']]
result4.replace('n','',inplace=True)
# Out:
# C:\Users\lfn\AppData\Local\Temp\ipykernel_20552\585728125.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result4.replace('n','',inplace=True)

# %%
result4
# Out:
#        company  staff_num    industry
# 0     创梦天地（乐逗）    500-999  软件和信息技术服务业
# 1         灿和兄弟    100-499         批发业
# 2         凉屋游戏      50-99  软件和信息技术服务业
# 3         风眼科技      50-99  软件和信息技术服务业
# 4           创酷      50-99  软件和信息技术服务业
# 5         九九互动    100-499  软件和信息技术服务业
# 6         第七大道      50-99  科技推广和应用服务业
# 7   星河互动（咸鱼游戏）      50-99  软件和信息技术服务业
# 8           易帆    100-499  软件和信息技术服务业
# 9         大梦龙途    100-499  软件和信息技术服务业
# 10        海拓时代    100-499         零售业
# 11        奇迅新游    100-499  软件和信息技术服务业
# 12        闲闲互娱      50-99  软件和信息技术服务业
# 13        迅龙创威    100-499  软件和信息技术服务业
# 14          望尘    100-499  软件和信息技术服务业
# 15        上海沐瞳    500-999    互联网和相关服务
# 16        北京途游    500-999  科技推广和应用服务业
# 17      厦门家乡互动    100-499  软件和信息技术服务业
# 18      北京龙创悦动    100-499  科技推广和应用服务业
# 19        友谊时光    100-499  软件和信息技术服务业
# 20         爱洛克    100-499  软件和信息技术服务业
# 21        蜗牛游戏    500-999    互联网和相关服务
# 22        幻塔网络    100-499  软件和信息技术服务业
# 23        天魂网络      50-99  软件和信息技术服务业
# ...

# %%
result4.to_excel('C:/Users/lfn/Desktop/companych4.xlsx',encoding = 'utf-8_sig')

# %%
company_list5 = [
['乐港'],
['游卡'],
['绝地'],
['无端'],
['炎魂'],
['掌盟'],
['非奇'],
['泛城'],
['心光流美'],
['不鸣'],
['星罗'],
['睿琪'],
['小影'],
['影笑'],
['格像'],
['掌中云'],
['星阅'],
['趣阅'],
['蓝帆'],
['宜格集团'],
['紫驰'],
['英佑'],
['金蝉布艺'],
['黑白调集团'],
['嗨宝贝'],
['优趣汇'],
['嘉云'],
['赛群'],
['目焦'],
['奥斯卡'],
['森帛'],
['杰希居'],
['两氢一氧'],
['禾观科技'],
['美家居'],
['微麦'],
['黯涉集团'],
['齐享'],
['多点互联'],
['踏搏'],
['幸福购'],
['易诺'],
['卧兔网络'],
['米趣'],
['棒米'],
['顺网'],
['天能电池'],
['健拓'],
['天娃教育'],
['猎板'],
['乐唱族'],
['尖兵'],
['吉喵云'],
['星盘起航'],
['杰晞'],
['微念'],
['风林'],
['宇视'],
['4399'],
['星辉'],
['百田'],
['君海'],
['三七'],
['易幻'],
['诗悦'],
['库洛'],
['天游'],
['尊游'],
['高图'],
['点盛'],
['黑胡子'],
['猎奇互娱'],
['深海'],
['金科文化'],
['因陀罗'],
['河马'],
['多益'],
['益世界'],
['趣炫'],
['波克城市广州'],
['西山居广州'],
['祖龙娱乐广州'],
['点点互动广州'],
['易娱广州'],
['BIGO'],
['触宝'],
['荔枝'],
['映客'],
['虎牙']]

# %%
for i in range(71,100):
    company = company_list5[i][0]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/search?key={}'.format(quote(company))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('div',{'class':'index_search-box__7YVh6'})[0]
    company_list5[i].append(info.find_all('a',{'class':'link-click'})[1].text)
    company_list5[i].append(info.find_all('span')[2].text)

# %%
company_list5
# Out:
# [['电魂', '胡建平', '2008-09-01'],
#  ['美盛', '袁贤苗', '2002-06-03'],
#  ['乐港', '崔中军', '1993-01-09'],
#  ['游卡', '杜彬', '2015-11-23'],
#  ['绝地', '俞甲子', '2013-08-06'],
#  ['无端', '郑明', '2010-01-18'],
#  ['妙聚', '陈博', '2013-09-06'],
#  ['炎魂', '陆叶青', '2013-01-14'],
#  ['金科', '周达', '1994-03-29'],
#  ['蜂派', '黄加祺', '2017-11-08'],
#  ['掌盟', '蔡红兵', '2007-06-15'],
#  ['非奇', '潘练武', '2010-09-14'],
#  ['泛城', '薛阳', '2005-04-15'],
#  ['卓亨', '赵海乐', '2011-08-18'],
#  ['渡口', '金津', '2005-04-07'],
#  ['心光流美', '谢彦乔', '2016-06-28'],
#  ['不鸣', '王希', '2012-05-07'],
#  ['星罗', '许欢', '2016-07-18'],
#  ['同趣', '吴守春', '2014-12-15'],
#  ['广州晶绮', '吴炜', '2014-07-30'],
#  ['深圳游戏科学'],
#  ['睿琪', '罗欢', '2009-05-31'],
#  ['小影', '韩晟', '2012-06-25'],
#  ['影笑', '季春娥', '2017-08-28'],
#  ['雅乐科技', '黄超', '2018-05-29'],
#  ['格像', '孙淳', '2014-06-24'],
#  ['掌中云', '洪森伟', '2017-07-11'],
#  ['星阅', '王磊', '2020-05-29'],
#  ['趣阅', '王涛', '2013-08-21'],
#  ['蓝帆', '刘文静', '2002-12-02'],
#  ['宜格集团', '张大勇', '2016-07-11'],
# ...

# %%
company_list5.index(['深圳游戏科学'])
# Out:
# 20

# %%
company_list5.index(['星辉'])
# Out:
# 70

# %%
for i in range(71,100):
    company = company_list5[i][0]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/search?key={}'.format(quote(company))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('a',{'class':'index_alink__zcia5 link-click'})[0]
    code = info['href'].split('/')[-1]
    company_list5[i].append(code)

# %%
for i in range(91,100):
    code = company_list5[i][3]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/company/{}'.format(quote(code))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('script',{'id':'__NEXT_DATA__'})
    strl = info[0].text
    regex1 = r'(?<="staffNumRange":).[0-9_\u4e00-\u9fa5]*'
    num = re.findall(regex1,strl)
    regex2 = r'(?<="industry":).[\u4e00-\u9fa5]*'
    industry = re.findall(regex2,strl)
    company_list5[i].append(num[0].replace('"',''))
    company_list5[i].append(industry[0].replace('"',''))

# %%
import pandas as pd
cl5 = pd.DataFrame(company_list5)
cl5.columns = ['company','legal_rep','launch_time','code','staff_num','industry']
result5 = cl5[['company','legal_rep','launch_time','staff_num','industry']]
result5.replace('n','',inplace=True)
# Out:
# C:\Users\lfn\AppData\Local\Temp\ipykernel_17136\547959447.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result5.replace('n','',inplace=True)

# %%
result5.to_excel('C:/Users/lfn/Desktop/companych5.xlsx',encoding = 'utf-8_sig')

# %%
company_list6 = [['小红书'],
['锐森'],
['罗科'],
['乐趣无限'],
['酷麦'],
['灵感互娱'],
['常相伴广州'],
['金山广州'],
['唯品会'],
['SHEIN'],
['棒谷科技'],
['逸仙'],
['澳鹏网络'],
['Fordeal'],
['细刻科技'],
['爆米科技'],
['蓝深科技'],
['usmile'],
['Shopee广州'],
['汇量'],
['钛动'],
['有米'],
['栗树'],
['赛脑'],
['舞飞'],
['虎示传媒广州'],
['猎豹移动广州'],
['常相伴'],
['微派'],
['创缘科技'],
['一鹭网络'],
['安徽刀锋互娱武汉'],
['森鑫科技'],
['精臣智慧标识科技'],
['乐薇电子商务'],
['飞猫环球'],
['伟崇网络'],
['达米恩科技'],
['博悦天诚'],
['研析科技'],
['海岸跃动'],
['亚兴国际'],
['亚声网络'],
['泉达网络'],
['哲牛跨境'],
['友梦互娱'],
['飓风无限'],
['北京百度武汉'],
['北京千橡网景（人人）武汉'],
['尚德机构武汉'],
['金顶置业'],
['昆仲科技'],
['Tap4Fun'],
['卓航科技'],
['星合互娱'],
['数字天空'],
['成都乐狗'],
['天象互动'],
['动鱼数码'],
['格斗科技'],
['哆可梦'],
['龙渊网络'],
['乐游志成'],
['嘉谊互娱'],
['余香科技'],
['天上友嘉'],
['数字狗'],
['睡神工作室'],
['Peakx Games'],
['乐信圣文'],
['云上微游'],
['深圳腾讯'],
['育碧成都'],
['上海黑桃互动'],
['厦门青瓷'],
['福建网龙'],
['品果科技'],
['乐山茂松'],
['云览科技'],
['傲梅科技'],
['艾欧比'],
['乐劲'],
['恒图科技'],
['珠海金山'],
['北京汉迪'],
['北京大圣互动'],
['鼎裕思'],
['宝妈乐购'],
['康特恩'],
['汪之滨'],
['三禧科技'],
['这伴科技'],
['润步顶火'],
['鹭鸣电子商务'],
['波斯顿电子商务'],
['直新科技'],
['领薪科技'],
['中启云创'],
['福建新时颖'],
['上海五五海淘']]

# %%
for i in range(0,100):
    company = company_list6[i][0]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/search?key={}'.format(quote(company))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('div',{'class':'index_search-box__7YVh6'})[0]
    company_list6[i].append(info.find_all('a',{'class':'link-click'})[1].text)
    company_list6[i].append(info.find_all('span')[2].text)

# %%
for i in range(0,100):
    company = company_list6[i][0]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/search?key={}'.format(quote(company))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('a',{'class':'index_alink__zcia5 link-click'})[0]
    code = info['href'].split('/')[-1]
    company_list6[i].append(code)

# %%
for i in range(95,100):
    code = company_list6[i][3]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/company/{}'.format(quote(code))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('script',{'id':'__NEXT_DATA__'})
    strl = info[0].text
    regex1 = r'(?<="staffNumRange":).[0-9_\u4e00-\u9fa5]*'
    num = re.findall(regex1,strl)
    regex2 = r'(?<="industry":).[\u4e00-\u9fa5]*'
    industry = re.findall(regex2,strl)
    company_list6[i].append(num[0].replace('"',''))
    company_list6[i].append(industry[0].replace('"',''))

# %%
import pandas as pd
cl6 = pd.DataFrame(company_list6)
cl6.columns = ['company','legal_rep','launch_time','code','staff_num','industry']
result6 = cl6[['company','legal_rep','launch_time','staff_num','industry']]
result6.replace('n','',inplace=True)
# Out:
# C:\Users\lfn\AppData\Local\Temp\ipykernel_17136\2344968018.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result6.replace('n','',inplace=True)

# %%
result6.to_excel('C:/Users/lfn/Desktop/companych6.xlsx',encoding = 'utf-8_sig')

# %%
company_list7=[['谷道科技（全球搜）'],
['银舵科技'],
['中云天下'],
['棕榈创想科技'],
['白云互动'],
['北京力植'],
['广州钛动'],
['深圳维卓'],
['深圳优美互动'],
['学语教育'],
['拙卓科技'],
['优译信息'],
['洋葱集团'],
['华星兄弟'],
['易我科技'],
['创思立信'],
['北京诺亚生活科技'],
['上海凯宴教育'],
['吉比特'],
['雷霆游戏'],
['青瓷游戏'],
['点触科技'],
['梦加网络'],
['厦门4399'],
['极致游戏'],
['勇仕网络'],
['摩多科技'],
['泡游'],
['延趣'],
['真有趣'],
['魔兔游戏'],
['酷游网络'],
['飞鱼游戏'],
['简创'],
['不妨游戏'],
['家乡互动'],
['沐游网络'],
['七七游'],
['好鸟科技'],
['微游互娱'],
['福州天盟数码'],
['美图'],
['美柚'],
['赛德沃克'],
['星罗网络'],
['他趣'],
['爱尔卓'],
['雨果网'],
['莱米诺'],
['心云飞羽'],
['姚明集团'],
['欣维发'],
['天信恒'],
['和新科技'],
['金多厦'],
['普维贸易'],
['麦金世纪'],
['紫色时空'],
['双安数科'],
['海湾科技'],
['宜众'],
['天创'],
['成功易'],
['亿联'],
['派美特'],
['视诚科技'],
['强力巨彩'],
['广开电子'],
['网宿'],
['巨龙信息'],
['星纵智能'],
['大博医疗'],
['奥佳华'],
['立林科技']]

# %%
len(company_list7)
# Out:
# 74

# %%
for i in range(0,74):
    company = company_list7[i][0]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/search?key={}'.format(quote(company))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('div',{'class':'index_search-box__7YVh6'})[0]
    company_list7[i].append(info.find_all('a',{'class':'link-click'})[1].text)
    company_list7[i].append(info.find_all('span')[2].text)

# %%
for i in range(0,74):
    company = company_list7[i][0]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/search?key={}'.format(quote(company))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('a',{'class':'index_alink__zcia5 link-click'})[0]
    code = info['href'].split('/')[-1]
    company_list7[i].append(code)

# %%
for i in range(16,74):
    code = company_list7[i][3]
    headers = {
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Host': 'www.tianyancha.com',
    'Cookie': 'HWWAFSESID=66e4934903dd2936f63; HWWAFSESTIME=1672920968564; csrfToken=BvciHaxqeh_VVPIGJLltFC-O; jsid=SEO-BING-ALL-SY-000001; TYCID=bce790208cf211edb726d7bb0c4d967f; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fcn.bing.com%2F%22%7D%2C%22identities%22%3A%22eyIkaWRlbnRpdHlfY29va2llX2lkIjoiMTg1ODFkYzM2NDUyODEtMDYzNmZlMWE4YzUzNy03YTU3NTQ3My0xMjk2MDAwLTE4NTgxZGMzNjQ2MTIxMiJ9%22%2C%22history_login_id%22%3A%7B%22name%22%3A%22%22%2C%22value%22%3A%22%22%7D%2C%22%24device_id%22%3A%2218581dc3645281-0636fe1a8c537-7a575473-1296000-18581dc36461212%22%7D; Hm_lvt_e92c8d65d92d534b0fc290df538b4758=1672920971; bannerFlag=true; searchSessionId=1672920983.60575816; Hm_lpvt_e92c8d65d92d534b0fc290df538b4758=1672921079',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
}
    url = 'https://www.tianyancha.com/company/{}'.format(quote(code))
    html = requests.get(url,headers = headers)
    soup = BeautifulSoup(html.text,features="html.parser")
    info = soup.find_all('script',{'id':'__NEXT_DATA__'})
    strl = info[0].text
    regex1 = r'(?<="staffNumRange":).[0-9_\u4e00-\u9fa5]*'
    num = re.findall(regex1,strl)
    regex2 = r'(?<="industry":).[\u4e00-\u9fa5]*'
    industry = re.findall(regex2,strl)
    company_list7[i].append(num[0].replace('"',''))
    company_list7[i].append(industry[0].replace('"',''))

# %%
company_list7
# Out:
# [['谷道科技（全球搜）', '蒲竞超', '2014-07-21', '2310832597', '小于50人', '软件和信息技术服务业'],
#  ['银舵科技', '商犇', '2015-04-24', '2353844431', '小于50人', '软件和信息技术服务业'],
#  ['中云天下', '李伟', '2014-04-16', '2347192477', '100', '研究和试验发展'],
#  ['棕榈创想科技', '常乐', '2015-11-24', '2352954312', '小于50人', '科技推广和应用服务业'],
#  ['白云互动', '刘应强', '2014-03-28', '1586979630', '50', '软件和信息技术服务业'],
#  ['北京力植', '丁国玉', '2013-07-15', '44760786', '50', '科技推广和应用服务业'],
#  ['广州钛动', '李述昊', '2017-09-18', '3096816582', '100', '软件和信息技术服务业'],
#  ['深圳维卓', '杨福祥', '2020-06-17', '3446069193', '', '商务服务业'],
#  ['深圳优美互动', '陈加富', '2016-06-29', '2959993586', '小于50人', '科技推广和应用服务业'],
#  ['学语教育', '王勃', '2018-04-08', '3173809992', '100', '软件和信息技术服务业'],
#  ['拙卓科技', '刘金松', '2012-07-12', '1689471458', '小于50人', '研究和试验发展'],
#  ['优译信息', '曾英', '2011-05-06', '2358174075', '小于50人', '科技推广和应用服务业'],
#  ['洋葱集团', '李淙', '2009-07-03', '3441905377', '小于50人', '研究和试验发展'],
#  ['华星兄弟', '骆文军', '2014-10-21', '2313388344', '100', '商务服务业'],
# ...

# %%
company_list7.index(['创思立信', '魏泽斌', '2021-08-19', '5097193438'])
# Out:
# 15

# %%
cl7 = pd.DataFrame(company_list7)
cl7.columns = ['company','legal_rep','launch_time','code','staff_num','industry']
result7 = cl7[['company','legal_rep','launch_time','staff_num','industry']]
result7.replace('n','',inplace=True)
result7.to_excel('C:/Users/lfn/Desktop/companych7.xlsx',encoding = 'utf-8_sig')
# Out:
# C:\Users\lfn\AppData\Local\Temp\ipykernel_17136\2429403677.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result7.replace('n','',inplace=True)
